# %% [markdown]
# #Python code for object recognition with fullscreen capture
# #Using YOLO v4 model for traning
# #Capable of recognizing multiple objects of different classes
# #Better results if used with fullscreen application

# %%
import numpy as np
import win32gui, win32ui, win32con
from PIL import Image
from time import sleep
import cv2 as cv
import os
import random
import time

# %%
class WindowCapture:
    w = 0
    h = 0
    hwnd = None

    def __init__(self, window_name):
        self.hwnd = win32gui.GetDesktopWindow()
        if not self.hwnd:
            raise Exception('Window not found: {}'.format(window_name))

        window_rect = win32gui.GetWindowRect(self.hwnd)
        self.w = window_rect[2] - window_rect[0]
        self.h = window_rect[3] - window_rect[1]

        border_pixels = 8
        titlebar_pixels = 30
        self.w = self.w - (border_pixels * 2)
        self.h = self.h - titlebar_pixels - border_pixels
        self.cropped_x = border_pixels
        self.cropped_y = titlebar_pixels

    def get_screenshot(self):
        wDC = win32gui.GetWindowDC(self.hwnd)
        dcObj = win32ui.CreateDCFromHandle(wDC)
        cDC = dcObj.CreateCompatibleDC()
        dataBitMap = win32ui.CreateBitmap()
        dataBitMap.CreateCompatibleBitmap(dcObj, self.w, self.h)
        cDC.SelectObject(dataBitMap)
        cDC.BitBlt((0, 0), (self.w, self.h), dcObj, (self.cropped_x, self.cropped_y), win32con.SRCCOPY)

        signedIntsArray = dataBitMap.GetBitmapBits(True)
        img = np.fromstring(signedIntsArray, dtype='uint8')
        img.shape = (self.h, self.w, 4)

        dcObj.DeleteDC()
        cDC.DeleteDC()
        win32gui.ReleaseDC(self.hwnd, wDC)
        win32gui.DeleteObject(dataBitMap.GetHandle())

        img = img[...,:3]
        img = np.ascontiguousarray(img) 
            
        return img

    def generate_image_dataset(self):
        if not os.path.exists("images"):
            os.mkdir("images")
        while(True):
            img = self.get_screenshot()
            im = Image.fromarray(img[..., [2, 1, 0]])
            im.save(f"./images/img_{len(os.listdir('images'))}.jpeg")
            sleep(1)
    
    def get_window_size(self):
        return (self.w, self.h)

# %%
class ImageProcessor:
    W = 0
    H = 0
    net = None
    ln = None
    classes = {}
    colors = []

    def __init__(self, img_size, cfg_file, weights_file):
        np.random.seed(42)
        self.net = cv.dnn.readNetFromDarknet(cfg_file, weights_file)
        self.net.setPreferableBackend(cv.dnn.DNN_BACKEND_OPENCV)
        self.ln = self.net.getLayerNames()
        self.ln = [self.ln[i-1] for i in self.net.getUnconnectedOutLayers()]
        self.W = img_size[0]
        self.H = img_size[1]
        
        with open('yolov4-tiny/obj.names', 'r') as file:
            lines = file.readlines()
        for i, line in enumerate(lines):
            self.classes[i] = line.strip()
        
        self.colors = [
            (255, 0, 0), 
            (0, 0, 255), 
        ]
        
    def proccess_image(self, img):

        blob = cv.dnn.blobFromImage(img, 1/255.0, (416, 416), swapRB=True, crop=False)
        self.net.setInput(blob)
        outputs = self.net.forward(self.ln)
        outputs = np.vstack(outputs)
        
        coordinates = self.get_coordinates(outputs, 0.5)

        self.draw_identified_objects(img, coordinates)

        return coordinates

    def get_coordinates(self, outputs, conf):

        boxes = []
        confidences = []
        classIDs = []

        for output in outputs:
            scores = output[5:]
            
            classID = np.argmax(scores)
            confidence = scores[classID]
            if confidence > conf:
                x, y, w, h = output[:4] * np.array([self.W, self.H, self.W, self.H])
                p0 = int(x - w//2), int(y - h//2)
                boxes.append([*p0, int(w), int(h)])
                confidences.append(float(confidence))
                classIDs.append(classID)

        indices = cv.dnn.NMSBoxes(boxes, confidences, conf, conf-0.1)

        if len(indices) == 0:
            return []

        coordinates = []
        for i in indices.flatten():
            (x, y) = (boxes[i][0], boxes[i][1])
            (w, h) = (boxes[i][2], boxes[i][3])

            coordinates.append({'x': x, 'y': y, 'w': w, 'h': h, 'class': classIDs[i], 'class_name': self.classes[classIDs[i]]})
        return coordinates

    def draw_identified_objects(self, img, coordinates):
        for coordinate in coordinates:
            x = coordinate['x']
            y = coordinate['y']
            w = coordinate['w']
            h = coordinate['h']
            classID = coordinate['class']
            
            color = self.colors[classID]
            
            cv.rectangle(img, (x, y), (x + w, y + h), color, 2)
            cv.putText(img, self.classes[classID], (x, y - 10), cv.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)
        cv.imshow('Computer vision',  img)

# %%
from win32gui import GetWindowText, GetForegroundWindow

time.sleep(5)

window_name = GetWindowText(GetForegroundWindow())
cfg_file_name = "./yolov4-tiny-custom.cfg"
weights_file_name = "yolov4-tiny-custom_last.weights"

print(window_name)

wincap = WindowCapture(window_name)
improc = ImageProcessor(wincap.get_window_size(), cfg_file_name, weights_file_name)

while(True):
    
    ss = wincap.get_screenshot()
    
    if cv.waitKey(1) == ord('q'):
        cv.destroyAllWindows()
        break

    coordinates = improc.proccess_image(ss)
    
    for coordinate in coordinates:
        print(coordinate)
# Out:
# soldier detection — Mozilla Firefox
# C:\Users\terox\AppData\Local\Temp\ipykernel_1672\2782022839.py:32: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   img = np.fromstring(signedIntsArray, dtype='uint8')
# {'x': 2224, 'y': 903, 'w': 67, 'h': 47, 'class': 0, 'class_name': 'friend'}
# {'x': 553, 'y': 325, 'w': 37, 'h': 70, 'class': 0, 'class_name': 'friend'}
# {'x': 550, 'y': 329, 'w': 35, 'h': 73, 'class': 0, 'class_name': 'friend'}
# {'x': 558, 'y': 334, 'w': 35, 'h': 78, 'class': 0, 'class_name': 'friend'}
# {'x': 551, 'y': 341, 'w': 41, 'h': 83, 'class': 0, 'class_name': 'friend'}
# {'x': 529, 'y': 346, 'w': 34, 'h': 68, 'class': 0, 'class_name': 'friend'}
# {'x': 624, 'y': 353, 'w': 34, 'h': 71, 'class': 0, 'class_name': 'friend'}
# {'x': 515, 'y': 344, 'w': 41, 'h': 75, 'class': 0, 'class_name': 'friend'}
# {'x': 515, 'y': 336, 'w': 36, 'h': 76, 'class': 0, 'class_name': 'friend'}
# {'x': 500, 'y': 333, 'w': 39, 'h': 76, 'class': 0, 'class_name': 'friend'}
# {'x': 496, 'y': 334, 'w': 41, 'h': 80, 'class': 0, 'class_name': 'friend'}
# {'x': 492, 'y': 335, 'w': 44, 'h': 79, 'class': 0, 'class_name': 'friend'}
# {'x': 1775, 'y': 974, 'w': 37, 'h': 81, 'class': 0, 'class_name': 'friend'}
# {'x': 1825, 'y': 984, 'w': 41, 'h': 66, 'class': 0, 'class_name': 'friend'}
# {'x': 496, 'y': 338, 'w': 44, 'h': 74, 'class': 0, 'class_name': 'friend'}
# {'x': 483, 'y': 333, 'w': 45, 'h': 82, 'class': 0, 'class_name': 'friend'}
# {'x': 1763, 'y': 971, 'w': 42, 'h': 82, 'class': 0, 'class_name': 'friend'}
# {'x': 684, 'y': 302, 'w': 38, 'h': 93, 'class': 0, 'class_name': 'friend'}
# {'x': 1863, 'y': 982, 'w': 28, 'h': 63, 'class': 0, 'class_name': 'friend'}
# {'x': 1855, 'y': 976, 'w': 31, 'h': 72, 'class': 0, 'class_name': 'friend'}
# {'x': 445, 'y': 299, 'w': 74, 'h': 134, 'class': 0, 'class_name': 'friend'}
# {'x': 786, 'y': 313, 'w': 52, 'h': 92, 'class': 0, 'class_name': 'friend'}
# {'x': 575, 'y': 334, 'w': 35, 'h': 75, 'class': 0, 'class_name': 'friend'}
# {'x': 1869, 'y': 977, 'w': 33, 'h': 70, 'class': 0, 'class_name': 'friend'}
# {'x': 439, 'y': 311, 'w': 67, 'h': 123, 'class': 0, 'class_name': 'friend'}
# {'x': 801, 'y': 334, 'w': 73, 'h': 125, 'class': 0, 'class_name': 'friend'}
# {'x': 1856, 'y': 972, 'w': 32, 'h': 70, 'class': 0, 'class_name': 'friend'}
# {'x': 435, 'y': 326, 'w': 54, 'h': 107, 'class': 0, 'class_name': 'friend'}
# {'x': 1747, 'y': 968, 'w': 44, 'h': 81, 'class': 0, 'class_name': 'friend'}
# {'x': 572, 'y': 337, 'w': 40, 'h': 86, 'class': 0, 'class_name': 'friend'}
# {'x': 805, 'y': 336, 'w': 70, 'h': 130, 'class': 0, 'class_name': 'friend'}
# {'x': 1723, 'y': 963, 'w': 45, 'h': 101, 'class': 0, 'class_name': 'friend'}
# {'x': 1852, 'y': 972, 'w': 30, 'h': 79, 'class': 0, 'class_name': 'friend'}
# {'x': 427, 'y': 320, 'w': 49, 'h': 122, 'class': 0, 'class_name': 'friend'}
# {'x': 423, 'y': 321, 'w': 49, 'h': 121, 'class': 0, 'class_name': 'friend'}
# {'x': 2073, 'y': 963, 'w': 82, 'h': 129, 'class': 0, 'class_name': 'friend'}
# {'x': 1717, 'y': 965, 'w': 48, 'h': 99, 'class': 0, 'class_name': 'friend'}
# {'x': 813, 'y': 332, 'w': 64, 'h': 120, 'class': 0, 'class_name': 'friend'}
# {'x': 1837, 'y': 964, 'w': 38, 'h': 98, 'class': 0, 'class_name': 'friend'}
# {'x': 565, 'y': 331, 'w': 32, 'h': 84, 'class': 0, 'class_name': 'friend'}
# {'x': 1701, 'y': 966, 'w': 47, 'h': 101, 'class': 0, 'class_name': 'friend'}
# {'x': 417, 'y': 326, 'w': 49, 'h': 129, 'class': 0, 'class_name': 'friend'}
# {'x': 1840, 'y': 963, 'w': 35, 'h': 94, 'class': 0, 'class_name': 'friend'}
# {'x': 818, 'y': 340, 'w': 73, 'h': 112, 'class': 0, 'class_name': 'friend'}
# {'x': 2086, 'y': 967, 'w': 70, 'h': 132, 'class': 0, 'class_name': 'friend'}
# {'x': 585, 'y': 336, 'w': 32, 'h': 72, 'class': 0, 'class_name': 'friend'}
# {'x': 566, 'y': 337, 'w': 34, 'h': 76, 'class': 0, 'class_name': 'friend'}
# {'x': 827, 'y': 333, 'w': 76, 'h': 140, 'class': 0, 'class_name': 'friend'}
# {'x': 421, 'y': 327, 'w': 58, 'h': 138, 'class': 0, 'class_name': 'friend'}
# {'x': 557, 'y': 332, 'w': 44, 'h': 98, 'class': 0, 'class_name': 'friend'}
# {'x': 356, 'y': 326, 'w': 63, 'h': 132, 'class': 0, 'class_name': 'friend'}
# {'x': 1865, 'y': 970, 'w': 32, 'h': 82, 'class': 0, 'class_name': 'friend'}
# {'x': 584, 'y': 334, 'w': 37, 'h': 81, 'class': 0, 'class_name': 'friend'}
# {'x': 1690, 'y': 966, 'w': 40, 'h': 104, 'class': 0, 'class_name': 'friend'}
# {'x': 588, 'y': 336, 'w': 38, 'h': 71, 'class': 0, 'class_name': 'friend'}
# {'x': 338, 'y': 316, 'w': 63, 'h': 145, 'class': 0, 'class_name': 'friend'}
# {'x': 1833, 'y': 964, 'w': 34, 'h': 92, 'class': 0, 'class_name': 'friend'}
# {'x': 420, 'y': 325, 'w': 58, 'h': 144, 'class': 0, 'class_name': 'friend'}
# {'x': 1707, 'y': 974, 'w': 43, 'h': 109, 'class': 0, 'class_name': 'friend'}
# {'x': 2085, 'y': 978, 'w': 77, 'h': 111, 'class': 0, 'class_name': 'friend'}
# {'x': 865, 'y': 334, 'w': 55, 'h': 108, 'class': 0, 'class_name': 'friend'}
# {'x': 398, 'y': 318, 'w': 64, 'h': 155, 'class': 0, 'class_name': 'friend'}
# {'x': 604, 'y': 330, 'w': 39, 'h': 74, 'class': 0, 'class_name': 'friend'}
# {'x': 1704, 'y': 965, 'w': 45, 'h': 133, 'class': 0, 'class_name': 'friend'}
# {'x': 310, 'y': 337, 'w': 67, 'h': 124, 'class': 0, 'class_name': 'friend'}
# {'x': 1829, 'y': 966, 'w': 35, 'h': 103, 'class': 0, 'class_name': 'friend'}
# {'x': 883, 'y': 320, 'w': 64, 'h': 128, 'class': 0, 'class_name': 'friend'}
# {'x': 627, 'y': 319, 'w': 39, 'h': 80, 'class': 0, 'class_name': 'friend'}
# {'x': 383, 'y': 303, 'w': 67, 'h': 169, 'class': 0, 'class_name': 'friend'}
# {'x': 1834, 'y': 964, 'w': 39, 'h': 99, 'class': 0, 'class_name': 'friend'}
# {'x': 681, 'y': 318, 'w': 47, 'h': 98, 'class': 0, 'class_name': 'friend'}
# {'x': 1967, 'y': 960, 'w': 51, 'h': 100, 'class': 0, 'class_name': 'friend'}
# {'x': 1700, 'y': 967, 'w': 47, 'h': 132, 'class': 0, 'class_name': 'friend'}
# {'x': 908, 'y': 313, 'w': 67, 'h': 117, 'class': 0, 'class_name': 'friend'}
# {'x': 1678, 'y': 955, 'w': 58, 'h': 154, 'class': 0, 'class_name': 'friend'}
# {'x': 627, 'y': 328, 'w': 36, 'h': 77, 'class': 0, 'class_name': 'friend'}
# {'x': 1824, 'y': 962, 'w': 46, 'h': 97, 'class': 0, 'class_name': 'friend'}
# {'x': 369, 'y': 306, 'w': 70, 'h': 170, 'class': 0, 'class_name': 'friend'}
# {'x': 562, 'y': 322, 'w': 39, 'h': 95, 'class': 0, 'class_name': 'friend'}
# {'x': 681, 'y': 320, 'w': 36, 'h': 98, 'class': 0, 'class_name': 'friend'}
# {'x': 916, 'y': 314, 'w': 77, 'h': 113, 'class': 0, 'class_name': 'friend'}
# {'x': 2155, 'y': 960, 'w': 69, 'h': 131, 'class': 0, 'class_name': 'friend'}
# {'x': 369, 'y': 314, 'w': 63, 'h': 167, 'class': 0, 'class_name': 'friend'}
# {'x': 1661, 'y': 945, 'w': 62, 'h': 165, 'class': 0, 'class_name': 'friend'}
# {'x': 648, 'y': 331, 'w': 38, 'h': 85, 'class': 0, 'class_name': 'friend'}
# {'x': 2191, 'y': 950, 'w': 52, 'h': 115, 'class': 0, 'class_name': 'friend'}
# {'x': 562, 'y': 330, 'w': 32, 'h': 80, 'class': 0, 'class_name': 'friend'}
# {'x': 718, 'y': 313, 'w': 39, 'h': 78, 'class': 0, 'class_name': 'friend'}
# {'x': 891, 'y': 302, 'w': 82, 'h': 132, 'class': 0, 'class_name': 'friend'}
# {'x': 2189, 'y': 946, 'w': 78, 'h': 116, 'class': 0, 'class_name': 'friend'}
# {'x': 367, 'y': 322, 'w': 67, 'h': 159, 'class': 0, 'class_name': 'friend'}
# {'x': 1653, 'y': 943, 'w': 57, 'h': 173, 'class': 0, 'class_name': 'friend'}
# {'x': 623, 'y': 333, 'w': 42, 'h': 94, 'class': 0, 'class_name': 'friend'}
# {'x': 553, 'y': 330, 'w': 39, 'h': 91, 'class': 0, 'class_name': 'friend'}
# {'x': 889, 'y': 290, 'w': 100, 'h': 156, 'class': 0, 'class_name': 'friend'}
# {'x': 360, 'y': 319, 'w': 73, 'h': 158, 'class': 0, 'class_name': 'friend'}
# {'x': 1649, 'y': 947, 'w': 56, 'h': 164, 'class': 0, 'class_name': 'friend'}
# {'x': 1916, 'y': 964, 'w': 42, 'h': 94, 'class': 0, 'class_name': 'friend'}
# {'x': 275, 'y': 315, 'w': 77, 'h': 142, 'class': 0, 'class_name': 'friend'}
# {'x': 887, 'y': 310, 'w': 123, 'h': 229, 'class': 0, 'class_name': 'friend'}
# {'x': 600, 'y': 331, 'w': 46, 'h': 101, 'class': 0, 'class_name': 'friend'}
# {'x': 1897, 'y': 974, 'w': 42, 'h': 76, 'class': 0, 'class_name': 'friend'}
# {'x': 338, 'y': 312, 'w': 67, 'h': 145, 'class': 0, 'class_name': 'friend'}
# {'x': 890, 'y': 308, 'w': 109, 'h': 235, 'class': 0, 'class_name': 'friend'}
# {'x': 252, 'y': 315, 'w': 51, 'h': 100, 'class': 0, 'class_name': 'friend'}
# {'x': 522, 'y': 326, 'w': 44, 'h': 87, 'class': 0, 'class_name': 'friend'}
# {'x': 1646, 'y': 966, 'w': 57, 'h': 145, 'class': 0, 'class_name': 'friend'}
# {'x': 2169, 'y': 926, 'w': 89, 'h': 158, 'class': 0, 'class_name': 'friend'}
# {'x': 580, 'y': 329, 'w': 41, 'h': 87, 'class': 0, 'class_name': 'friend'}
# {'x': 876, 'y': 305, 'w': 115, 'h': 221, 'class': 0, 'class_name': 'friend'}
# {'x': 1809, 'y': 958, 'w': 40, 'h': 103, 'class': 0, 'class_name': 'friend'}
# {'x': 2174, 'y': 956, 'w': 93, 'h': 214, 'class': 0, 'class_name': 'friend'}
# {'x': 512, 'y': 317, 'w': 42, 'h': 89, 'class': 0, 'class_name': 'friend'}
# {'x': 319, 'y': 299, 'w': 70, 'h': 155, 'class': 0, 'class_name': 'friend'}
# {'x': 228, 'y': 300, 'w': 57, 'h': 114, 'class': 0, 'class_name': 'friend'}
# {'x': 1635, 'y': 953, 'w': 60, 'h': 155, 'class': 0, 'class_name': 'friend'}
# {'x': 1885, 'y': 971, 'w': 32, 'h': 79, 'class': 0, 'class_name': 'friend'}
# {'x': 241, 'y': 298, 'w': 76, 'h': 124, 'class': 0, 'class_name': 'friend'}
# {'x': 2173, 'y': 957, 'w': 87, 'h': 209, 'class': 0, 'class_name': 'friend'}
# {'x': 1625, 'y': 955, 'w': 45, 'h': 133, 'class': 0, 'class_name': 'friend'}
# {'x': 826, 'y': 302, 'w': 111, 'h': 212, 'class': 0, 'class_name': 'friend'}
# {'x': 135, 'y': 295, 'w': 76, 'h': 112, 'class': 0, 'class_name': 'friend'}
# {'x': 1534, 'y': 946, 'w': 36, 'h': 122, 'class': 0, 'class_name': 'friend'}
# {'x': 843, 'y': 313, 'w': 148, 'h': 314, 'class': 0, 'class_name': 'friend'}
# {'x': 2172, 'y': 937, 'w': 91, 'h': 233, 'class': 0, 'class_name': 'friend'}
# {'x': 131, 'y': 306, 'w': 93, 'h': 109, 'class': 0, 'class_name': 'friend'}
# {'x': 1603, 'y': 936, 'w': 61, 'h': 152, 'class': 0, 'class_name': 'friend'}
# {'x': 1814, 'y': 950, 'w': 38, 'h': 99, 'class': 0, 'class_name': 'friend'}
# {'x': 481, 'y': 311, 'w': 47, 'h': 80, 'class': 0, 'class_name': 'friend'}
# {'x': 1515, 'y': 938, 'w': 42, 'h': 113, 'class': 0, 'class_name': 'friend'}
# {'x': 4, 'y': 298, 'w': 78, 'h': 108, 'class': 0, 'class_name': 'friend'}
# {'x': 871, 'y': 277, 'w': 369, 'h': 434, 'class': 0, 'class_name': 'friend'}
# {'x': 2120, 'y': 939, 'w': 74, 'h': 202, 'class': 0, 'class_name': 'friend'}
# {'x': 425, 'y': 303, 'w': 48, 'h': 86, 'class': 0, 'class_name': 'friend'}
# {'x': 1530, 'y': 948, 'w': 46, 'h': 111, 'class': 0, 'class_name': 'friend'}
# {'x': 2121, 'y': 947, 'w': 135, 'h': 311, 'class': 0, 'class_name': 'friend'}
# {'x': 373, 'y': 302, 'w': 51, 'h': 86, 'class': 0, 'class_name': 'friend'}
# {'x': 215, 'y': 301, 'w': 78, 'h': 110, 'class': 0, 'class_name': 'friend'}
# {'x': 2116, 'y': 922, 'w': 417, 'h': 396, 'class': 0, 'class_name': 'friend'}
# {'x': 84, 'y': 287, 'w': 81, 'h': 133, 'class': 0, 'class_name': 'friend'}
# {'x': 773, 'y': 290, 'w': 71, 'h': 115, 'class': 0, 'class_name': 'friend'}
# {'x': 1597, 'y': 937, 'w': 61, 'h': 110, 'class': 0, 'class_name': 'friend'}
# {'x': 780, 'y': 284, 'w': 68, 'h': 127, 'class': 0, 'class_name': 'friend'}
# {'x': 742, 'y': 290, 'w': 68, 'h': 124, 'class': 0, 'class_name': 'friend'}
# {'x': 721, 'y': 296, 'w': 76, 'h': 123, 'class': 0, 'class_name': 'friend'}
# {'x': 2045, 'y': 922, 'w': 73, 'h': 120, 'class': 0, 'class_name': 'friend'}
# {'x': 690, 'y': 290, 'w': 83, 'h': 147, 'class': 0, 'class_name': 'friend'}
# {'x': 349, 'y': 311, 'w': 52, 'h': 71, 'class': 0, 'class_name': 'friend'}
# {'x': 1992, 'y': 929, 'w': 83, 'h': 126, 'class': 0, 'class_name': 'friend'}
# {'x': 668, 'y': 286, 'w': 62, 'h': 164, 'class': 0, 'class_name': 'friend'}
# {'x': 307, 'y': 312, 'w': 40, 'h': 77, 'class': 0, 'class_name': 'friend'}
# {'x': 1966, 'y': 928, 'w': 71, 'h': 146, 'class': 0, 'class_name': 'friend'}
# {'x': 623, 'y': 275, 'w': 85, 'h': 231, 'class': 0, 'class_name': 'friend'}
# {'x': 602, 'y': 283, 'w': 119, 'h': 234, 'class': 0, 'class_name': 'friend'}
# {'x': 1955, 'y': 930, 'w': 50, 'h': 155, 'class': 0, 'class_name': 'friend'}
# {'x': 609, 'y': 287, 'w': 110, 'h': 261, 'class': 0, 'class_name': 'friend'}
# {'x': 1907, 'y': 918, 'w': 77, 'h': 196, 'class': 0, 'class_name': 'friend'}
# {'x': 615, 'y': 279, 'w': 90, 'h': 288, 'class': 0, 'class_name': 'friend'}
# {'x': 647, 'y': 268, 'w': 104, 'h': 246, 'class': 0, 'class_name': 'friend'}
# {'x': 1885, 'y': 920, 'w': 104, 'h': 233, 'class': 0, 'class_name': 'friend'}
# {'x': 709, 'y': 261, 'w': 115, 'h': 279, 'class': 0, 'class_name': 'friend'}
# {'x': 1882, 'y': 928, 'w': 116, 'h': 257, 'class': 0, 'class_name': 'friend'}
# {'x': 554, 'y': 260, 'w': 125, 'h': 372, 'class': 0, 'class_name': 'friend'}
# {'x': 770, 'y': 239, 'w': 178, 'h': 322, 'class': 0, 'class_name': 'friend'}
# {'x': 1885, 'y': 906, 'w': 95, 'h': 311, 'class': 0, 'class_name': 'friend'}
# {'x': 1989, 'y': 896, 'w': 108, 'h': 273, 'class': 0, 'class_name': 'friend'}
# {'x': 1852, 'y': 882, 'w': 107, 'h': 362, 'class': 0, 'class_name': 'friend'}
# {'x': 2055, 'y': 858, 'w': 150, 'h': 349, 'class': 0, 'class_name': 'friend'}
# {'x': 367, 'y': 226, 'w': 188, 'h': 454, 'class': 0, 'class_name': 'friend'}
# {'x': 496, 'y': 244, 'w': 163, 'h': 302, 'class': 0, 'class_name': 'friend'}
# {'x': 1706, 'y': 874, 'w': 184, 'h': 377, 'class': 0, 'class_name': 'friend'}
# {'x': 523, 'y': 257, 'w': 121, 'h': 288, 'class': 1, 'class_name': 'enemy'}
# {'x': 546, 'y': 253, 'w': 130, 'h': 264, 'class': 1, 'class_name': 'enemy'}
# {'x': 546, 'y': 225, 'w': 103, 'h': 288, 'class': 1, 'class_name': 'enemy'}
# {'x': 1807, 'y': 890, 'w': 111, 'h': 297, 'class': 1, 'class_name': 'enemy'}
# {'x': 1821, 'y': 875, 'w': 123, 'h': 280, 'class': 1, 'class_name': 'enemy'}
# {'x': 556, 'y': 248, 'w': 93, 'h': 248, 'class': 1, 'class_name': 'enemy'}
# {'x': 581, 'y': 262, 'w': 87, 'h': 255, 'class': 1, 'class_name': 'enemy'}
# {'x': 1824, 'y': 875, 'w': 89, 'h': 269, 'class': 1, 'class_name': 'enemy'}
# {'x': 1817, 'y': 879, 'w': 101, 'h': 255, 'class': 1, 'class_name': 'enemy'}
# {'x': 827, 'y': 285, 'w': 201, 'h': 335, 'class': 1, 'class_name': 'enemy'}
# {'x': 1856, 'y': 903, 'w': 79, 'h': 255, 'class': 1, 'class_name': 'enemy'}
# {'x': 2313, 'y': 919, 'w': 210, 'h': 334, 'class': 0, 'class_name': 'friend'}
# {'x': 309, 'y': 246, 'w': 154, 'h': 291, 'class': 0, 'class_name': 'friend'}
# {'x': 1583, 'y': 899, 'w': 176, 'h': 275, 'class': 1, 'class_name': 'enemy'}
# {'x': 478, 'y': 311, 'w': 108, 'h': 109, 'class': 0, 'class_name': 'friend'}
# {'x': 596, 'y': 295, 'w': 85, 'h': 131, 'class': 0, 'class_name': 'friend'}
# {'x': 598, 'y': 296, 'w': 86, 'h': 131, 'class': 0, 'class_name': 'friend'}
# {'x': 578, 'y': 303, 'w': 95, 'h': 134, 'class': 0, 'class_name': 'friend'}
# {'x': 557, 'y': 301, 'w': 114, 'h': 134, 'class': 0, 'class_name': 'friend'}
# {'x': 1858, 'y': 936, 'w': 105, 'h': 124, 'class': 0, 'class_name': 'friend'}
# {'x': 617, 'y': 310, 'w': 98, 'h': 142, 'class': 0, 'class_name': 'friend'}
# {'x': 624, 'y': 319, 'w': 118, 'h': 145, 'class': 0, 'class_name': 'friend'}
# {'x': 1846, 'y': 942, 'w': 85, 'h': 131, 'class': 0, 'class_name': 'friend'}
# {'x': 628, 'y': 320, 'w': 157, 'h': 182, 'class': 0, 'class_name': 'friend'}
# {'x': 610, 'y': 360, 'w': 206, 'h': 185, 'class': 0, 'class_name': 'friend'}
# {'x': 1906, 'y': 955, 'w': 121, 'h': 195, 'class': 1, 'class_name': 'enemy'}
# {'x': 1894, 'y': 987, 'w': 161, 'h': 202, 'class': 0, 'class_name': 'friend'}
# {'x': 683, 'y': 285, 'w': 222, 'h': 248, 'class': 0, 'class_name': 'friend'}
# {'x': 553, 'y': 268, 'w': 196, 'h': 308, 'class': 0, 'class_name': 'friend'}
# {'x': 487, 'y': 271, 'w': 174, 'h': 384, 'class': 0, 'class_name': 'friend'}
# {'x': 1846, 'y': 907, 'w': 176, 'h': 306, 'class': 0, 'class_name': 'friend'}
# {'x': 394, 'y': 289, 'w': 223, 'h': 333, 'class': 0, 'class_name': 'friend'}
# {'x': 1754, 'y': 909, 'w': 169, 'h': 393, 'class': 0, 'class_name': 'friend'}
# {'x': 292, 'y': 292, 'w': 316, 'h': 390, 'class': 0, 'class_name': 'friend'}
# {'x': 1699, 'y': 943, 'w': 206, 'h': 321, 'class': 0, 'class_name': 'friend'}
# {'x': 242, 'y': 292, 'w': 338, 'h': 362, 'class': 0, 'class_name': 'friend'}
# {'x': 1554, 'y': 913, 'w': 327, 'h': 383, 'class': 0, 'class_name': 'friend'}
# {'x': 1532, 'y': 906, 'w': 318, 'h': 398, 'class': 0, 'class_name': 'friend'}
# {'x': 380, 'y': 315, 'w': 80, 'h': 133, 'class': 0, 'class_name': 'friend'}
# {'x': 584, 'y': 311, 'w': 76, 'h': 142, 'class': 0, 'class_name': 'friend'}
# {'x': 410, 'y': 307, 'w': 67, 'h': 138, 'class': 0, 'class_name': 'friend'}
# {'x': 417, 'y': 297, 'w': 68, 'h': 157, 'class': 0, 'class_name': 'friend'}
# {'x': 608, 'y': 300, 'w': 78, 'h': 160, 'class': 0, 'class_name': 'friend'}
# {'x': 255, 'y': 313, 'w': 40, 'h': 84, 'class': 0, 'class_name': 'friend'}
# {'x': 773, 'y': 282, 'w': 477, 'h': 354, 'class': 0, 'class_name': 'friend'}
# {'x': 426, 'y': 311, 'w': 70, 'h': 138, 'class': 0, 'class_name': 'friend'}
# {'x': 221, 'y': 313, 'w': 42, 'h': 97, 'class': 0, 'class_name': 'friend'}
# {'x': 1696, 'y': 946, 'w': 58, 'h': 137, 'class': 0, 'class_name': 'friend'}
# {'x': 1864, 'y': 951, 'w': 67, 'h': 139, 'class': 0, 'class_name': 'friend'}
# {'x': 440, 'y': 304, 'w': 77, 'h': 154, 'class': 0, 'class_name': 'friend'}
# {'x': 174, 'y': 316, 'w': 52, 'h': 98, 'class': 0, 'class_name': 'friend'}
# {'x': 2031, 'y': 926, 'w': 495, 'h': 346, 'class': 0, 'class_name': 'friend'}
# {'x': 445, 'y': 307, 'w': 84, 'h': 164, 'class': 0, 'class_name': 'friend'}
# {'x': 1702, 'y': 953, 'w': 62, 'h': 133, 'class': 0, 'class_name': 'friend'}
# {'x': 2201, 'y': 955, 'w': 335, 'h': 323, 'class': 0, 'class_name': 'friend'}
# {'x': 105, 'y': 314, 'w': 75, 'h': 109, 'class': 0, 'class_name': 'friend'}
# {'x': 446, 'y': 314, 'w': 71, 'h': 156, 'class': 0, 'class_name': 'friend'}
# {'x': 1718, 'y': 932, 'w': 73, 'h': 170, 'class': 0, 'class_name': 'friend'}
# {'x': 435, 'y': 310, 'w': 70, 'h': 155, 'class': 0, 'class_name': 'friend'}
# {'x': 1724, 'y': 937, 'w': 70, 'h': 166, 'class': 0, 'class_name': 'friend'}
# {'x': 418, 'y': 298, 'w': 63, 'h': 136, 'class': 0, 'class_name': 'friend'}
# {'x': 1716, 'y': 953, 'w': 77, 'h': 158, 'class': 0, 'class_name': 'friend'}
# {'x': 622, 'y': 309, 'w': 95, 'h': 198, 'class': 0, 'class_name': 'friend'}
# {'x': 851, 'y': 321, 'w': 107, 'h': 228, 'class': 0, 'class_name': 'friend'}
# {'x': 2293, 'y': 999, 'w': 235, 'h': 280, 'class': 0, 'class_name': 'friend'}
# {'x': 331, 'y': 295, 'w': 73, 'h': 139, 'class': 0, 'class_name': 'friend'}
# {'x': 518, 'y': 291, 'w': 94, 'h': 205, 'class': 0, 'class_name': 'friend'}
# {'x': 2239, 'y': 988, 'w': 134, 'h': 245, 'class': 0, 'class_name': 'friend'}
# {'x': 237, 'y': 281, 'w': 79, 'h': 152, 'class': 0, 'class_name': 'friend'}
# {'x': 377, 'y': 282, 'w': 93, 'h': 216, 'class': 0, 'class_name': 'friend'}
# {'x': 1902, 'y': 946, 'w': 72, 'h': 197, 'class': 0, 'class_name': 'friend'}
# {'x': 2138, 'y': 949, 'w': 77, 'h': 237, 'class': 0, 'class_name': 'friend'}
# {'x': 655, 'y': 293, 'w': 71, 'h': 178, 'class': 0, 'class_name': 'friend'}
# {'x': 290, 'y': 264, 'w': 94, 'h': 237, 'class': 0, 'class_name': 'friend'}
# {'x': 196, 'y': 268, 'w': 72, 'h': 162, 'class': 0, 'class_name': 'friend'}
# {'x': 137, 'y': 270, 'w': 58, 'h': 110, 'class': 0, 'class_name': 'friend'}
# {'x': 1793, 'y': 919, 'w': 78, 'h': 219, 'class': 0, 'class_name': 'friend'}
# {'x': 1612, 'y': 937, 'w': 59, 'h': 133, 'class': 0, 'class_name': 'friend'}
# {'x': 222, 'y': 262, 'w': 129, 'h': 264, 'class': 0, 'class_name': 'friend'}
# {'x': 143, 'y': 286, 'w': 58, 'h': 86, 'class': 0, 'class_name': 'friend'}
# {'x': 1657, 'y': 911, 'w': 86, 'h': 231, 'class': 0, 'class_name': 'friend'}
# {'x': 633, 'y': 273, 'w': 63, 'h': 192, 'class': 0, 'class_name': 'friend'}
# {'x': 1514, 'y': 924, 'w': 74, 'h': 150, 'class': 0, 'class_name': 'friend'}
# {'x': 1466, 'y': 914, 'w': 60, 'h': 160, 'class': 0, 'class_name': 'friend'}
# {'x': 1573, 'y': 909, 'w': 82, 'h': 220, 'class': 0, 'class_name': 'friend'}
# {'x': 1891, 'y': 915, 'w': 65, 'h': 173, 'class': 0, 'class_name': 'friend'}
# {'x': 283, 'y': 288, 'w': 73, 'h': 134, 'class': 0, 'class_name': 'friend'}
# {'x': 197, 'y': 270, 'w': 77, 'h': 144, 'class': 0, 'class_name': 'friend'}
# {'x': 1905, 'y': 927, 'w': 59, 'h': 160, 'class': 0, 'class_name': 'friend'}
# {'x': 597, 'y': 277, 'w': 64, 'h': 183, 'class': 0, 'class_name': 'friend'}
# {'x': 558, 'y': 258, 'w': 63, 'h': 164, 'class': 0, 'class_name': 'friend'}
# {'x': 1871, 'y': 914, 'w': 57, 'h': 174, 'class': 0, 'class_name': 'friend'}
# {'x': 532, 'y': 237, 'w': 85, 'h': 211, 'class': 0, 'class_name': 'friend'}
# {'x': 1475, 'y': 893, 'w': 76, 'h': 160, 'class': 0, 'class_name': 'friend'}
# {'x': 500, 'y': 227, 'w': 86, 'h': 237, 'class': 0, 'class_name': 'friend'}
# {'x': 1838, 'y': 906, 'w': 55, 'h': 147, 'class': 0, 'class_name': 'friend'}
# {'x': 483, 'y': 208, 'w': 92, 'h': 266, 'class': 0, 'class_name': 'friend'}
# {'x': 1810, 'y': 885, 'w': 75, 'h': 186, 'class': 0, 'class_name': 'friend'}
# {'x': 1770, 'y': 863, 'w': 90, 'h': 240, 'class': 0, 'class_name': 'friend'}
# {'x': 426, 'y': 202, 'w': 114, 'h': 263, 'class': 0, 'class_name': 'friend'}
# {'x': 1774, 'y': 842, 'w': 77, 'h': 281, 'class': 0, 'class_name': 'friend'}
# {'x': 1038, 'y': 286, 'w': 49, 'h': 60, 'class': 0, 'class_name': 'friend'}
# {'x': 321, 'y': 180, 'w': 147, 'h': 319, 'class': 0, 'class_name': 'friend'}
# {'x': 248, 'y': 196, 'w': 144, 'h': 324, 'class': 0, 'class_name': 'friend'}
# {'x': 849, 'y': 284, 'w': 34, 'h': 65, 'class': 0, 'class_name': 'friend'}
# {'x': 1710, 'y': 833, 'w': 91, 'h': 279, 'class': 0, 'class_name': 'friend'}
# {'x': 1600, 'y': 814, 'w': 132, 'h': 325, 'class': 1, 'class_name': 'enemy'}
# {'x': 1515, 'y': 815, 'w': 144, 'h': 347, 'class': 0, 'class_name': 'friend'}
# {'x': 2047, 'y': 914, 'w': 33, 'h': 66, 'class': 0, 'class_name': 'friend'}
# {'x': 697, 'y': 273, 'w': 38, 'h': 74, 'class': 0, 'class_name': 'friend'}
# {'x': 687, 'y': 281, 'w': 37, 'h': 60, 'class': 1, 'class_name': 'enemy'}
# {'x': 656, 'y': 271, 'w': 38, 'h': 66, 'class': 1, 'class_name': 'enemy'}
# {'x': 639, 'y': 253, 'w': 39, 'h': 76, 'class': 0, 'class_name': 'friend'}
# {'x': 633, 'y': 255, 'w': 37, 'h': 80, 'class': 0, 'class_name': 'friend'}
# {'x': 1895, 'y': 883, 'w': 45, 'h': 92, 'class': 0, 'class_name': 'friend'}
# {'x': 633, 'y': 265, 'w': 33, 'h': 66, 'class': 1, 'class_name': 'enemy'}
# {'x': 618, 'y': 261, 'w': 37, 'h': 81, 'class': 1, 'class_name': 'enemy'}
# {'x': 591, 'y': 301, 'w': 49, 'h': 76, 'class': 0, 'class_name': 'friend'}
# {'x': 1885, 'y': 883, 'w': 40, 'h': 95, 'class': 1, 'class_name': 'enemy'}
# {'x': 1865, 'y': 951, 'w': 50, 'h': 63, 'class': 0, 'class_name': 'friend'}
# {'x': 1772, 'y': 946, 'w': 45, 'h': 65, 'class': 0, 'class_name': 'friend'}
# {'x': 483, 'y': 348, 'w': 47, 'h': 85, 'class': 0, 'class_name': 'friend'}
# {'x': 484, 'y': 346, 'w': 49, 'h': 84, 'class': 0, 'class_name': 'friend'}
# {'x': 1748, 'y': 967, 'w': 49, 'h': 97, 'class': 0, 'class_name': 'friend'}
# {'x': 496, 'y': 347, 'w': 51, 'h': 81, 'class': 0, 'class_name': 'friend'}
# {'x': 1753, 'y': 969, 'w': 42, 'h': 96, 'class': 0, 'class_name': 'friend'}
# {'x': 513, 'y': 356, 'w': 54, 'h': 67, 'class': 0, 'class_name': 'friend'}
# {'x': 532, 'y': 345, 'w': 53, 'h': 86, 'class': 0, 'class_name': 'friend'}
# {'x': 551, 'y': 341, 'w': 49, 'h': 94, 'class': 0, 'class_name': 'friend'}
# {'x': 1900, 'y': 973, 'w': 53, 'h': 90, 'class': 0, 'class_name': 'friend'}
# {'x': 1922, 'y': 972, 'w': 45, 'h': 90, 'class': 0, 'class_name': 'friend'}
# {'x': 1676, 'y': 956, 'w': 118, 'h': 283, 'class': 0, 'class_name': 'friend'}
# {'x': 1364, 'y': 936, 'w': 121, 'h': 139, 'class': 1, 'class_name': 'enemy'}
# {'x': 605, 'y': 370, 'w': 97, 'h': 140, 'class': 1, 'class_name': 'enemy'}
# {'x': 634, 'y': 377, 'w': 68, 'h': 104, 'class': 1, 'class_name': 'enemy'}
# {'x': 1890, 'y': 1000, 'w': 84, 'h': 143, 'class': 1, 'class_name': 'enemy'}
# {'x': 624, 'y': 381, 'w': 55, 'h': 76, 'class': 1, 'class_name': 'enemy'}
# {'x': 1907, 'y': 1012, 'w': 73, 'h': 100, 'class': 1, 'class_name': 'enemy'}
# {'x': 1895, 'y': 1017, 'w': 57, 'h': 77, 'class': 1, 'class_name': 'enemy'}
# {'x': 643, 'y': 341, 'w': 47, 'h': 64, 'class': 0, 'class_name': 'friend'}
# {'x': 654, 'y': 311, 'w': 46, 'h': 76, 'class': 0, 'class_name': 'friend'}
# {'x': 672, 'y': 286, 'w': 47, 'h': 82, 'class': 0, 'class_name': 'friend'}
# {'x': 1857, 'y': 956, 'w': 55, 'h': 48, 'class': 0, 'class_name': 'friend'}
# {'x': 202, 'y': 309, 'w': 49, 'h': 52, 'class': 0, 'class_name': 'friend'}
# {'x': 136, 'y': 310, 'w': 50, 'h': 51, 'class': 0, 'class_name': 'friend'}
# {'x': 309, 'y': 313, 'w': 49, 'h': 46, 'class': 0, 'class_name': 'friend'}
# {'x': 1523, 'y': 950, 'w': 42, 'h': 46, 'class': 0, 'class_name': 'friend'}
# {'x': 1500, 'y': 950, 'w': 38, 'h': 49, 'class': 0, 'class_name': 'friend'}
# {'x': 163, 'y': 350, 'w': 56, 'h': 61, 'class': 0, 'class_name': 'friend'}
# {'x': 160, 'y': 353, 'w': 55, 'h': 61, 'class': 0, 'class_name': 'friend'}
# {'x': 157, 'y': 355, 'w': 56, 'h': 58, 'class': 0, 'class_name': 'friend'}
# {'x': 1664, 'y': 985, 'w': 42, 'h': 44, 'class': 1, 'class_name': 'enemy'}
# {'x': 1650, 'y': 989, 'w': 36, 'h': 50, 'class': 1, 'class_name': 'enemy'}
# {'x': 391, 'y': 354, 'w': 44, 'h': 65, 'class': 0, 'class_name': 'friend'}
# {'x': 1770, 'y': 912, 'w': 45, 'h': 61, 'class': 0, 'class_name': 'friend'}
# {'x': 1618, 'y': 970, 'w': 48, 'h': 52, 'class': 0, 'class_name': 'friend'}
# {'x': 655, 'y': 289, 'w': 32, 'h': 42, 'class': 0, 'class_name': 'friend'}
# {'x': 1620, 'y': 972, 'w': 46, 'h': 50, 'class': 0, 'class_name': 'friend'}
# {'x': 487, 'y': 278, 'w': 42, 'h': 48, 'class': 0, 'class_name': 'friend'}
# {'x': 489, 'y': 268, 'w': 43, 'h': 56, 'class': 0, 'class_name': 'friend'}
# {'x': 134, 'y': 344, 'w': 59, 'h': 55, 'class': 0, 'class_name': 'friend'}
# {'x': 486, 'y': 270, 'w': 44, 'h': 56, 'class': 0, 'class_name': 'friend'}
# {'x': 113, 'y': 345, 'w': 57, 'h': 57, 'class': 0, 'class_name': 'friend'}
# {'x': 483, 'y': 270, 'w': 48, 'h': 55, 'class': 0, 'class_name': 'friend'}
# {'x': 1597, 'y': 973, 'w': 57, 'h': 58, 'class': 0, 'class_name': 'friend'}
# {'x': 483, 'y': 270, 'w': 45, 'h': 58, 'class': 0, 'class_name': 'friend'}
# {'x': 1918, 'y': 934, 'w': 41, 'h': 44, 'class': 0, 'class_name': 'friend'}
# {'x': 711, 'y': 367, 'w': 51, 'h': 47, 'class': 1, 'class_name': 'enemy'}
# {'x': 747, 'y': 355, 'w': 58, 'h': 53, 'class': 1, 'class_name': 'enemy'}
# {'x': 736, 'y': 354, 'w': 61, 'h': 53, 'class': 0, 'class_name': 'friend'}
# {'x': 696, 'y': 357, 'w': 54, 'h': 57, 'class': 1, 'class_name': 'enemy'}
# {'x': 684, 'y': 355, 'w': 51, 'h': 62, 'class': 1, 'class_name': 'enemy'}
# {'x': 1967, 'y': 991, 'w': 51, 'h': 56, 'class': 0, 'class_name': 'friend'}
# {'x': 1952, 'y': 989, 'w': 53, 'h': 65, 'class': 0, 'class_name': 'friend'}
# {'x': 597, 'y': 365, 'w': 60, 'h': 60, 'class': 1, 'class_name': 'enemy'}
# {'x': 604, 'y': 350, 'w': 57, 'h': 75, 'class': 1, 'class_name': 'enemy'}
# {'x': 2032, 'y': 993, 'w': 50, 'h': 58, 'class': 0, 'class_name': 'friend'}
# {'x': 615, 'y': 355, 'w': 61, 'h': 81, 'class': 0, 'class_name': 'friend'}
# {'x': 154, 'y': 377, 'w': 53, 'h': 66, 'class': 0, 'class_name': 'friend'}
# {'x': 229, 'y': 366, 'w': 47, 'h': 64, 'class': 1, 'class_name': 'enemy'}
# {'x': 1666, 'y': 970, 'w': 41, 'h': 52, 'class': 1, 'class_name': 'enemy'}
# {'x': 1679, 'y': 966, 'w': 42, 'h': 43, 'class': 1, 'class_name': 'enemy'}
# {'x': 551, 'y': 303, 'w': 49, 'h': 56, 'class': 1, 'class_name': 'enemy'}
# {'x': 557, 'y': 300, 'w': 46, 'h': 58, 'class': 1, 'class_name': 'enemy'}
# {'x': 1820, 'y': 931, 'w': 49, 'h': 60, 'class': 0, 'class_name': 'friend'}
# {'x': 1827, 'y': 933, 'w': 45, 'h': 53, 'class': 1, 'class_name': 'enemy'}
# {'x': 89, 'y': 223, 'w': 52, 'h': 69, 'class': 0, 'class_name': 'friend'}
# {'x': 1846, 'y': 928, 'w': 50, 'h': 62, 'class': 1, 'class_name': 'enemy'}
# {'x': 371, 'y': 207, 'w': 54, 'h': 55, 'class': 0, 'class_name': 'friend'}
# {'x': 380, 'y': 208, 'w': 56, 'h': 53, 'class': 0, 'class_name': 'friend'}
# {'x': 63, 'y': 273, 'w': 59, 'h': 65, 'class': 0, 'class_name': 'friend'}
# {'x': 1960, 'y': 789, 'w': 58, 'h': 66, 'class': 0, 'class_name': 'friend'}
# {'x': 512, 'y': 203, 'w': 36, 'h': 49, 'class': 0, 'class_name': 'friend'}
# {'x': 481, 'y': 225, 'w': 34, 'h': 51, 'class': 0, 'class_name': 'friend'}
# {'x': 1801, 'y': 852, 'w': 40, 'h': 55, 'class': 0, 'class_name': 'friend'}
# {'x': 1767, 'y': 897, 'w': 35, 'h': 50, 'class': 1, 'class_name': 'enemy'}
# {'x': 538, 'y': 266, 'w': 44, 'h': 53, 'class': 1, 'class_name': 'enemy'}
# {'x': 1811, 'y': 900, 'w': 42, 'h': 50, 'class': 1, 'class_name': 'enemy'}
# {'x': 641, 'y': 300, 'w': 73, 'h': 130, 'class': 1, 'class_name': 'enemy'}
# {'x': 656, 'y': 299, 'w': 73, 'h': 135, 'class': 0, 'class_name': 'friend'}
# {'x': 657, 'y': 323, 'w': 85, 'h': 127, 'class': 0, 'class_name': 'friend'}
# {'x': 1911, 'y': 935, 'w': 77, 'h': 130, 'class': 0, 'class_name': 'friend'}
# {'x': 642, 'y': 319, 'w': 85, 'h': 131, 'class': 0, 'class_name': 'friend'}
# {'x': 658, 'y': 324, 'w': 85, 'h': 131, 'class': 0, 'class_name': 'friend'}
# {'x': 666, 'y': 330, 'w': 85, 'h': 145, 'class': 0, 'class_name': 'friend'}
# {'x': 1918, 'y': 944, 'w': 82, 'h': 137, 'class': 1, 'class_name': 'enemy'}
# {'x': 1936, 'y': 940, 'w': 73, 'h': 150, 'class': 0, 'class_name': 'friend'}
# {'x': 662, 'y': 334, 'w': 101, 'h': 149, 'class': 1, 'class_name': 'enemy'}
# {'x': 675, 'y': 339, 'w': 103, 'h': 151, 'class': 0, 'class_name': 'friend'}
# {'x': 1937, 'y': 969, 'w': 90, 'h': 144, 'class': 0, 'class_name': 'friend'}
# {'x': 1939, 'y': 967, 'w': 91, 'h': 152, 'class': 1, 'class_name': 'enemy'}
# {'x': 713, 'y': 331, 'w': 87, 'h': 177, 'class': 0, 'class_name': 'friend'}
# {'x': 716, 'y': 308, 'w': 98, 'h': 211, 'class': 0, 'class_name': 'friend'}
# {'x': 1985, 'y': 974, 'w': 88, 'h': 171, 'class': 0, 'class_name': 'friend'}
# {'x': 714, 'y': 291, 'w': 100, 'h': 224, 'class': 0, 'class_name': 'friend'}
# {'x': 685, 'y': 301, 'w': 110, 'h': 202, 'class': 1, 'class_name': 'enemy'}
# {'x': 1992, 'y': 914, 'w': 94, 'h': 239, 'class': 0, 'class_name': 'friend'}
# {'x': 659, 'y': 287, 'w': 115, 'h': 202, 'class': 0, 'class_name': 'friend'}
# {'x': 672, 'y': 314, 'w': 92, 'h': 169, 'class': 0, 'class_name': 'friend'}
# {'x': 685, 'y': 346, 'w': 92, 'h': 150, 'class': 0, 'class_name': 'friend'}
# {'x': 1943, 'y': 977, 'w': 89, 'h': 146, 'class': 0, 'class_name': 'friend'}
# {'x': 702, 'y': 356, 'w': 87, 'h': 138, 'class': 0, 'class_name': 'friend'}
# {'x': 684, 'y': 350, 'w': 99, 'h': 146, 'class': 1, 'class_name': 'enemy'}
# {'x': 1980, 'y': 989, 'w': 81, 'h': 138, 'class': 0, 'class_name': 'friend'}
# {'x': 677, 'y': 357, 'w': 93, 'h': 134, 'class': 1, 'class_name': 'enemy'}
# {'x': 1964, 'y': 984, 'w': 87, 'h': 145, 'class': 0, 'class_name': 'friend'}
# {'x': 1947, 'y': 988, 'w': 97, 'h': 139, 'class': 1, 'class_name': 'enemy'}
# {'x': 674, 'y': 365, 'w': 92, 'h': 125, 'class': 1, 'class_name': 'enemy'}
# {'x': 669, 'y': 362, 'w': 104, 'h': 124, 'class': 1, 'class_name': 'enemy'}
# {'x': 1949, 'y': 989, 'w': 88, 'h': 131, 'class': 1, 'class_name': 'enemy'}
# {'x': 1949, 'y': 1000, 'w': 86, 'h': 115, 'class': 1, 'class_name': 'enemy'}
# {'x': 1952, 'y': 991, 'w': 79, 'h': 123, 'class': 1, 'class_name': 'enemy'}
# {'x': 672, 'y': 358, 'w': 95, 'h': 132, 'class': 1, 'class_name': 'enemy'}
# {'x': 672, 'y': 360, 'w': 95, 'h': 128, 'class': 1, 'class_name': 'enemy'}
# {'x': 670, 'y': 352, 'w': 100, 'h': 136, 'class': 1, 'class_name': 'enemy'}
# {'x': 1942, 'y': 990, 'w': 83, 'h': 128, 'class': 1, 'class_name': 'enemy'}
# {'x': 673, 'y': 342, 'w': 95, 'h': 147, 'class': 1, 'class_name': 'enemy'}
# {'x': 1943, 'y': 993, 'w': 85, 'h': 123, 'class': 1, 'class_name': 'enemy'}
# {'x': 1944, 'y': 988, 'w': 99, 'h': 127, 'class': 1, 'class_name': 'enemy'}
# {'x': 1949, 'y': 975, 'w': 91, 'h': 145, 'class': 1, 'class_name': 'enemy'}
# {'x': 660, 'y': 304, 'w': 94, 'h': 170, 'class': 1, 'class_name': 'enemy'}
# {'x': 661, 'y': 241, 'w': 124, 'h': 254, 'class': 1, 'class_name': 'enemy'}
# {'x': 692, 'y': 254, 'w': 108, 'h': 231, 'class': 1, 'class_name': 'enemy'}
# {'x': 1936, 'y': 938, 'w': 89, 'h': 157, 'class': 1, 'class_name': 'enemy'}
# {'x': 1942, 'y': 846, 'w': 129, 'h': 286, 'class': 1, 'class_name': 'enemy'}
# {'x': 1958, 'y': 863, 'w': 116, 'h': 264, 'class': 1, 'class_name': 'enemy'}
# {'x': 691, 'y': 254, 'w': 110, 'h': 229, 'class': 1, 'class_name': 'enemy'}
# {'x': 666, 'y': 243, 'w': 148, 'h': 226, 'class': 1, 'class_name': 'enemy'}
# {'x': 620, 'y': 253, 'w': 156, 'h': 197, 'class': 1, 'class_name': 'enemy'}
# {'x': 1947, 'y': 878, 'w': 129, 'h': 225, 'class': 0, 'class_name': 'friend'}
# {'x': 630, 'y': 295, 'w': 124, 'h': 150, 'class': 1, 'class_name': 'enemy'}
# {'x': 1910, 'y': 884, 'w': 128, 'h': 201, 'class': 1, 'class_name': 'enemy'}
# {'x': 606, 'y': 313, 'w': 130, 'h': 134, 'class': 1, 'class_name': 'enemy'}
# {'x': 1915, 'y': 939, 'w': 101, 'h': 130, 'class': 1, 'class_name': 'enemy'}
# {'x': 1902, 'y': 952, 'w': 114, 'h': 125, 'class': 1, 'class_name': 'enemy'}
# {'x': 1899, 'y': 944, 'w': 97, 'h': 134, 'class': 1, 'class_name': 'enemy'}
# {'x': 1885, 'y': 951, 'w': 100, 'h': 134, 'class': 1, 'class_name': 'enemy'}
# {'x': 1879, 'y': 937, 'w': 94, 'h': 148, 'class': 1, 'class_name': 'enemy'}
# {'x': 1873, 'y': 925, 'w': 91, 'h': 165, 'class': 1, 'class_name': 'enemy'}
# {'x': 598, 'y': 239, 'w': 98, 'h': 207, 'class': 1, 'class_name': 'enemy'}
# {'x': 1862, 'y': 861, 'w': 112, 'h': 225, 'class': 1, 'class_name': 'enemy'}
# {'x': 587, 'y': 238, 'w': 106, 'h': 209, 'class': 1, 'class_name': 'enemy'}
# {'x': 568, 'y': 245, 'w': 105, 'h': 201, 'class': 1, 'class_name': 'enemy'}
# {'x': 562, 'y': 252, 'w': 97, 'h': 186, 'class': 1, 'class_name': 'enemy'}
# {'x': 1838, 'y': 881, 'w': 102, 'h': 201, 'class': 1, 'class_name': 'enemy'}
# {'x': 1840, 'y': 896, 'w': 89, 'h': 172, 'class': 1, 'class_name': 'enemy'}
# {'x': 583, 'y': 245, 'w': 76, 'h': 184, 'class': 1, 'class_name': 'enemy'}
# {'x': 1835, 'y': 881, 'w': 101, 'h': 197, 'class': 1, 'class_name': 'enemy'}
# {'x': 579, 'y': 223, 'w': 102, 'h': 206, 'class': 1, 'class_name': 'enemy'}
# {'x': 588, 'y': 209, 'w': 99, 'h': 226, 'class': 1, 'class_name': 'enemy'}
# {'x': 589, 'y': 228, 'w': 95, 'h': 202, 'class': 1, 'class_name': 'enemy'}
# {'x': 1860, 'y': 850, 'w': 96, 'h': 227, 'class': 1, 'class_name': 'enemy'}
# {'x': 571, 'y': 259, 'w': 81, 'h': 163, 'class': 1, 'class_name': 'enemy'}
# {'x': 543, 'y': 222, 'w': 103, 'h': 197, 'class': 0, 'class_name': 'friend'}
# {'x': 529, 'y': 230, 'w': 81, 'h': 178, 'class': 0, 'class_name': 'friend'}
# {'x': 1847, 'y': 893, 'w': 79, 'h': 166, 'class': 1, 'class_name': 'enemy'}
# {'x': 513, 'y': 252, 'w': 90, 'h': 155, 'class': 0, 'class_name': 'friend'}
# {'x': 1819, 'y': 881, 'w': 92, 'h': 164, 'class': 0, 'class_name': 'friend'}
# {'x': 507, 'y': 236, 'w': 83, 'h': 163, 'class': 0, 'class_name': 'friend'}
# {'x': 1788, 'y': 878, 'w': 92, 'h': 158, 'class': 0, 'class_name': 'friend'}
# {'x': 499, 'y': 236, 'w': 80, 'h': 166, 'class': 0, 'class_name': 'friend'}
# {'x': 1788, 'y': 879, 'w': 69, 'h': 154, 'class': 0, 'class_name': 'friend'}
# {'x': 510, 'y': 255, 'w': 79, 'h': 145, 'class': 0, 'class_name': 'friend'}
# {'x': 1772, 'y': 881, 'w': 83, 'h': 153, 'class': 0, 'class_name': 'friend'}
# {'x': 527, 'y': 240, 'w': 71, 'h': 153, 'class': 0, 'class_name': 'friend'}
# {'x': 529, 'y': 237, 'w': 71, 'h': 157, 'class': 0, 'class_name': 'friend'}
# {'x': 520, 'y': 247, 'w': 68, 'h': 156, 'class': 0, 'class_name': 'friend'}
# {'x': 1807, 'y': 885, 'w': 60, 'h': 143, 'class': 0, 'class_name': 'friend'}
# {'x': 510, 'y': 247, 'w': 73, 'h': 154, 'class': 0, 'class_name': 'friend'}
# {'x': 1778, 'y': 898, 'w': 66, 'h': 128, 'class': 0, 'class_name': 'friend'}
# {'x': 1777, 'y': 900, 'w': 67, 'h': 124, 'class': 0, 'class_name': 'friend'}
# {'x': 312, 'y': 244, 'w': 42, 'h': 56, 'class': 0, 'class_name': 'friend'}
# {'x': 305, 'y': 252, 'w': 35, 'h': 57, 'class': 0, 'class_name': 'friend'}
# {'x': 285, 'y': 250, 'w': 39, 'h': 60, 'class': 0, 'class_name': 'friend'}
# {'x': 273, 'y': 256, 'w': 36, 'h': 64, 'class': 0, 'class_name': 'friend'}
# {'x': 262, 'y': 267, 'w': 33, 'h': 59, 'class': 0, 'class_name': 'friend'}
# {'x': 237, 'y': 253, 'w': 48, 'h': 70, 'class': 0, 'class_name': 'friend'}
# {'x': 1512, 'y': 893, 'w': 45, 'h': 60, 'class': 0, 'class_name': 'friend'}
# {'x': 1479, 'y': 889, 'w': 43, 'h': 72, 'class': 0, 'class_name': 'friend'}
# {'x': 451, 'y': 289, 'w': 47, 'h': 61, 'class': 0, 'class_name': 'friend'}
# {'x': 453, 'y': 292, 'w': 47, 'h': 69, 'class': 0, 'class_name': 'friend'}
# {'x': 457, 'y': 272, 'w': 48, 'h': 76, 'class': 1, 'class_name': 'enemy'}
# {'x': 455, 'y': 257, 'w': 37, 'h': 76, 'class': 1, 'class_name': 'enemy'}
# {'x': 1735, 'y': 906, 'w': 38, 'h': 68, 'class': 0, 'class_name': 'friend'}
# {'x': 449, 'y': 263, 'w': 41, 'h': 79, 'class': 1, 'class_name': 'enemy'}
# {'x': 445, 'y': 270, 'w': 41, 'h': 77, 'class': 1, 'class_name': 'enemy'}
# {'x': 434, 'y': 262, 'w': 43, 'h': 82, 'class': 1, 'class_name': 'enemy'}
# {'x': 431, 'y': 273, 'w': 47, 'h': 79, 'class': 1, 'class_name': 'enemy'}
# {'x': 431, 'y': 297, 'w': 50, 'h': 62, 'class': 1, 'class_name': 'enemy'}
# {'x': 448, 'y': 280, 'w': 45, 'h': 65, 'class': 1, 'class_name': 'enemy'}
# {'x': 437, 'y': 275, 'w': 55, 'h': 81, 'class': 0, 'class_name': 'friend'}
# {'x': 355, 'y': 249, 'w': 54, 'h': 81, 'class': 0, 'class_name': 'friend'}
# {'x': 622, 'y': 247, 'w': 45, 'h': 115, 'class': 1, 'class_name': 'enemy'}
# {'x': 216, 'y': -1, 'w': 502, 'h': 322, 'class': 0, 'class_name': 'friend'}
# {'x': 1873, 'y': 877, 'w': 51, 'h': 133, 'class': 1, 'class_name': 'enemy'}
# {'x': 192, 'y': -17, 'w': 519, 'h': 377, 'class': 0, 'class_name': 'friend'}
# {'x': 129, 'y': -10, 'w': 467, 'h': 383, 'class': 0, 'class_name': 'friend'}
# {'x': 1467, 'y': 642, 'w': 422, 'h': 332, 'class': 0, 'class_name': 'friend'}
# {'x': 549, 'y': 333, 'w': 114, 'h': 232, 'class': 1, 'class_name': 'enemy'}
# {'x': 496, 'y': 294, 'w': 145, 'h': 267, 'class': 1, 'class_name': 'enemy'}
# {'x': 1818, 'y': 941, 'w': 115, 'h': 265, 'class': 1, 'class_name': 'enemy'}
# {'x': 453, 'y': 279, 'w': 119, 'h': 318, 'class': 1, 'class_name': 'enemy'}
# {'x': 1778, 'y': 927, 'w': 127, 'h': 261, 'class': 1, 'class_name': 'enemy'}
# {'x': 434, 'y': 297, 'w': 133, 'h': 278, 'class': 0, 'class_name': 'friend'}
# {'x': 494, 'y': 284, 'w': 128, 'h': 271, 'class': 1, 'class_name': 'enemy'}
# {'x': 1701, 'y': 897, 'w': 155, 'h': 344, 'class': 1, 'class_name': 'enemy'}
# {'x': 1710, 'y': 925, 'w': 141, 'h': 278, 'class': 0, 'class_name': 'friend'}
# {'x': 521, 'y': 278, 'w': 136, 'h': 270, 'class': 1, 'class_name': 'enemy'}
# {'x': 546, 'y': 266, 'w': 114, 'h': 292, 'class': 0, 'class_name': 'friend'}
# {'x': 1767, 'y': 901, 'w': 134, 'h': 281, 'class': 1, 'class_name': 'enemy'}
# {'x': 558, 'y': 292, 'w': 130, 'h': 226, 'class': 0, 'class_name': 'friend'}
# {'x': 576, 'y': 267, 'w': 107, 'h': 245, 'class': 0, 'class_name': 'friend'}
# {'x': 1851, 'y': 935, 'w': 93, 'h': 231, 'class': 1, 'class_name': 'enemy'}
# {'x': 730, 'y': 292, 'w': 132, 'h': 193, 'class': 1, 'class_name': 'enemy'}
# {'x': 794, 'y': 281, 'w': 131, 'h': 219, 'class': 1, 'class_name': 'enemy'}
# {'x': 2077, 'y': 913, 'w': 119, 'h': 212, 'class': 1, 'class_name': 'enemy'}
# {'x': 754, 'y': 348, 'w': 87, 'h': 176, 'class': 0, 'class_name': 'friend'}
# {'x': 545, 'y': 263, 'w': 39, 'h': 46, 'class': 1, 'class_name': 'enemy'}
# {'x': 506, 'y': 259, 'w': 40, 'h': 56, 'class': 1, 'class_name': 'enemy'}
# {'x': 1763, 'y': 902, 'w': 35, 'h': 58, 'class': 0, 'class_name': 'friend'}
# {'x': 1717, 'y': 911, 'w': 35, 'h': 49, 'class': 0, 'class_name': 'friend'}
# {'x': 449, 'y': 277, 'w': 42, 'h': 71, 'class': 0, 'class_name': 'friend'}
# {'x': 436, 'y': 274, 'w': 46, 'h': 70, 'class': 1, 'class_name': 'enemy'}
# {'x': 1722, 'y': 909, 'w': 35, 'h': 76, 'class': 1, 'class_name': 'enemy'}
# {'x': 1704, 'y': 908, 'w': 47, 'h': 71, 'class': 1, 'class_name': 'enemy'}
# {'x': 1610, 'y': 886, 'w': 46, 'h': 88, 'class': 0, 'class_name': 'friend'}
# {'x': 1610, 'y': 884, 'w': 43, 'h': 95, 'class': 0, 'class_name': 'friend'}
# {'x': 266, 'y': 271, 'w': 44, 'h': 89, 'class': 0, 'class_name': 'friend'}
# {'x': 1588, 'y': 888, 'w': 44, 'h': 98, 'class': 0, 'class_name': 'friend'}
# {'x': 2216, 'y': 1127, 'w': 104, 'h': 93, 'class': 0, 'class_name': 'friend'}
# {'x': 773, 'y': 467, 'w': 97, 'h': 101, 'class': 0, 'class_name': 'friend'}
# {'x': 1900, 'y': 989, 'w': 89, 'h': 162, 'class': 1, 'class_name': 'enemy'}
# {'x': 1912, 'y': 758, 'w': 98, 'h': 129, 'class': 1, 'class_name': 'enemy'}
# {'x': 663, 'y': 120, 'w': 76, 'h': 134, 'class': 0, 'class_name': 'friend'}
# {'x': 426, 'y': 258, 'w': 47, 'h': 76, 'class': 0, 'class_name': 'friend'}
# {'x': 1944, 'y': 764, 'w': 69, 'h': 131, 'class': 0, 'class_name': 'friend'}
# {'x': 446, 'y': 264, 'w': 40, 'h': 73, 'class': 0, 'class_name': 'friend'}
# {'x': 441, 'y': 273, 'w': 46, 'h': 76, 'class': 0, 'class_name': 'friend'}
# {'x': 441, 'y': 269, 'w': 47, 'h': 82, 'class': 0, 'class_name': 'friend'}
# {'x': 446, 'y': 261, 'w': 45, 'h': 78, 'class': 0, 'class_name': 'friend'}
# {'x': 1720, 'y': 894, 'w': 49, 'h': 78, 'class': 0, 'class_name': 'friend'}
# {'x': 440, 'y': 260, 'w': 47, 'h': 79, 'class': 0, 'class_name': 'friend'}
# {'x': 1714, 'y': 899, 'w': 45, 'h': 63, 'class': 0, 'class_name': 'friend'}
# {'x': 310, 'y': 239, 'w': 44, 'h': 72, 'class': 0, 'class_name': 'friend'}
# {'x': 286, 'y': 246, 'w': 41, 'h': 76, 'class': 0, 'class_name': 'friend'}
# {'x': 826, 'y': 337, 'w': 38, 'h': 58, 'class': 0, 'class_name': 'friend'}
# {'x': 1895, 'y': 937, 'w': 59, 'h': 97, 'class': 0, 'class_name': 'friend'}
# {'x': 640, 'y': 334, 'w': 104, 'h': 166, 'class': 0, 'class_name': 'friend'}
# {'x': 650, 'y': 313, 'w': 115, 'h': 228, 'class': 0, 'class_name': 'friend'}
# {'x': 666, 'y': 307, 'w': 122, 'h': 307, 'class': 0, 'class_name': 'friend'}
# {'x': 1920, 'y': 974, 'w': 91, 'h': 161, 'class': 0, 'class_name': 'friend'}
# {'x': 648, 'y': 310, 'w': 230, 'h': 378, 'class': 0, 'class_name': 'friend'}
# {'x': 1934, 'y': 952, 'w': 89, 'h': 222, 'class': 1, 'class_name': 'enemy'}
# {'x': 1929, 'y': 944, 'w': 138, 'h': 307, 'class': 0, 'class_name': 'friend'}
# {'x': 593, 'y': 370, 'w': 50, 'h': 102, 'class': 1, 'class_name': 'enemy'}
# {'x': 1803, 'y': 846, 'w': 129, 'h': 262, 'class': 0, 'class_name': 'friend'}
# {'x': 1038, 'y': 320, 'w': 54, 'h': 84, 'class': 1, 'class_name': 'enemy'}
# {'x': 1857, 'y': 900, 'w': 136, 'h': 203, 'class': 1, 'class_name': 'enemy'}
# {'x': 585, 'y': 237, 'w': 98, 'h': 143, 'class': 1, 'class_name': 'enemy'}
# {'x': 483, 'y': 143, 'w': 119, 'h': 213, 'class': 1, 'class_name': 'enemy'}
# {'x': 1870, 'y': 865, 'w': 89, 'h': 151, 'class': 1, 'class_name': 'enemy'}
